# %%
import json
import csv

# Función para leer el archivo JSON que contenga la Carta Porte v3.1 a evaluar.
def read_json(file_path):
    try:
        with open(file_path, 'r', encoding='utf-8') as file:      # Lectura del JSON en codificación para mostrar los acentos 
            data = json.load(file)
            # print(f"Data read from file: {data}")                 # Muestra contenido de todo el archivo
            if isinstance(data, dict):
                return data
            else:
                print("El archivo no contiene una estructura de JSON válida.")
                return None
    except json.JSONDecodeError as e:
        print(f"Error al decodificar el JSON: {e}")                      # En caso de JSON inválido
        return None
    except Exception as e:
        print(f"Error encontrado: {e}")
        return None

# Funcion para leer el catálogo de Productos y servicios del SAT para carta porte. Regresa el código de "MaterialPeligroso" 
def search_CP_code(code_to_search):								
	with open(catalog_data, encoding='utf-8') as csvfile:
		contents = csv.reader(csvfile, delimiter=',', quotechar='"')
		for row in contents:
			if row[0] == code_to_search:
				return row[3]

# Función para iterar sobre los productos en el JSON
def iterate_products(json_data):
	try:
		complemento = json_data.get('Complemento', {})            # Desecha el resto del JSON y obtiene solo lo contenido en Mercancias > Mercancia
		carta_porte = complemento.get('CartaPorte31', {})
		mercancias = carta_porte.get('Mercancias', {})
		productos = mercancias.get('Mercancia', [])

		for index,producto in enumerate(productos):               # Recorre todas las mercancías incluidas en el JSON, mostrando los valores referentes al material peligroso
			clave_material_peligroso = search_CP_code(producto.get('BienesTransp'))		# Busca la clave indicada en "BienesTransp" en los catálogos del SAT
			
			# Si la clave es "1" el JSON debe tener "Sí" en campo "MaterialPeligroso"
			if clave_material_peligroso == "1":			
				if producto.get('MaterialPeligroso') == "Sí":
					print(f'• Mercancia[{index}] ✅ .')
				else:
					print(f'• Mercancia[{index}] ❌ : Para "BienesTransp":"{producto.get("BienesTransp")}", el campo "MaterialPeligroso" debe estar indicado y ser "Sí" según lo indicado en los catálogos del SAT ({clave_material_peligroso})')	

			# Si la clave es "0" el JSON no debe tener el campo "MaterialPeligroso"
			if clave_material_peligroso == "0":			
				if producto.get('MaterialPeligroso'):
					print(f'• Mercancia[{index}] ❌ : Para "BienesTransp":"{producto.get("BienesTransp")}", el campo "MaterialPeligroso" no debe ser incluido según lo indicado en los catálogos del SAT ({clave_material_peligroso})')		
				else:
					print(f'• Mercancia[{index}] ✅ .')
					
			# Si la clave es "0,1" el JSON debe tener "Sí" o "No" en campo "MaterialPeligroso"
			elif clave_material_peligroso == "0,1":		
				if producto.get('MaterialPeligroso') == "Sí" or producto.get('MaterialPeligroso') == "No":
					print(f'• Mercancia[{index}] ✅ .')
				else:
					print(f'• Mercancia[{index}] ❌ : Para "BienesTransp":"{producto.get("BienesTransp")}", el campo "MaterialPeligroso" debe ser incluido según lo indicado en los catálogos del SAT ({clave_material_peligroso})')

			elif clave_material_peligroso == None:								
				print(f'• Mercancia[{index}] ❌  "BienesTransp":"{producto.get("BienesTransp")}" no encontrado en los catalogos de productos y servicios de Carta Porte v3.1')

	except KeyError as e:
		print(f"Key not found: {e}")
	except TypeError as e:
		print(f"Type error: {e}")


# Programa
file_path = 'CartaPorte.json'  			# Ruta del archivo JSON de la Carta Porte v3.1
catalog_data = 'c_ClaveProdServCP.csv'	# Ruta del catálogo de Productos & Servicios de Carta Porte v3.1

json_data = read_json(file_path)   
iterate_products(json_data) if json_data else print("Error al crear objeto a partir de archivo JSON.")
# Out:
# • Mercancia[0] ✅ .
# • Mercancia[1] ✅ .
# • Mercancia[2] ✅ .
# • Mercancia[3] ✅ .
# • Mercancia[4] ✅ .
# • Mercancia[5] ✅ .
# • Mercancia[6] ✅ .
# • Mercancia[7] ✅ .
# • Mercancia[8] ✅ .
# • Mercancia[9] ✅ .
# • Mercancia[10] ✅ .
# • Mercancia[11] ✅ .
# • Mercancia[12] ✅ .
# • Mercancia[13] ✅ .
# • Mercancia[14] ✅ .
# • Mercancia[15] ✅ .
# • Mercancia[16] ✅ .
# • Mercancia[17] ✅ .
# • Mercancia[18] ✅ .
# • Mercancia[19] ❌ : Para "BienesTransp":"01010101", el campo "MaterialPeligroso" debe ser incluido según lo indicado en los catálogos del SAT (0,1)
# • Mercancia[20] ✅ .
# • Mercancia[21] ✅ .
# • Mercancia[22] ✅ .
# • Mercancia[23] ✅ .
# • Mercancia[24] ✅ .
# • Mercancia[25] ✅ .
# • Mercancia[26] ✅ .
# • Mercancia[27] ✅ .
# • Mercancia[28] ✅ .
# • Mercancia[29] ✅ .
# • Mercancia[30] ❌ : Para "BienesTransp":"20122100", el campo "MaterialPeligroso" debe ser incluido según lo indicado en los catálogos del SAT (0,1)
# • Mercancia[31] ✅ .
# • Mercancia[32] ✅ .
# • Mercancia[33] ✅ .
# • Mercancia[34] ✅ .
# • Mercancia[35] ❌ : Para "BienesTransp":"32131000", el campo "MaterialPeligroso" debe ser incluido según lo indicado en los catálogos del SAT (0,1)
# • Mercancia[36] ✅ .
# • Mercancia[37] ✅ .
# • Mercancia[38] ✅ .
# • Mercancia[39] ✅ .
# • Mercancia[40] ✅ .
# • Mercancia[41] ✅ .
# • Mercancia[42] ✅ .
# • Mercancia[43] ✅ .
# • Mercancia[44] ✅ .
# • Mercancia[45] ✅ .
# • Mercancia[46] ✅ .
# • Mercancia[47] ✅ .
# • Mercancia[48] ✅ .
# • Mercancia[49] ✅ .
# • Mercancia[50] ✅ .
# • Mercancia[51] ✅ .
# • Mercancia[52] ✅ .
# • Mercancia[53] ✅ .
# • Mercancia[54] ✅ .
# • Mercancia[55] ✅ .
# • Mercancia[56] ✅ .
# • Mercancia[57] ✅ .
# • Mercancia[58] ✅ .
# • Mercancia[59] ✅ .
# • Mercancia[60] ✅ .
# • Mercancia[61] ✅ .
# • Mercancia[62] ✅ .
# • Mercancia[63] ✅ .
# • Mercancia[64] ✅ .
# • Mercancia[65] ✅ .
# • Mercancia[66] ✅ .
# • Mercancia[67] ✅ .
# • Mercancia[68] ✅ .
# • Mercancia[69] ✅ .
# • Mercancia[70] ✅ .
# • Mercancia[71] ✅ .
# • Mercancia[72] ✅ .
# • Mercancia[73] ✅ .
# • Mercancia[74] ✅ .
# • Mercancia[75] ✅ .
# • Mercancia[76] ✅ .
# • Mercancia[77] ✅ .
# • Mercancia[78] ✅ .
# • Mercancia[79] ✅ .
# • Mercancia[80] ❌ : Para "BienesTransp":"01010101", el campo "MaterialPeligroso" debe ser incluido según lo indicado en los catálogos del SAT (0,1)
# • Mercancia[81] ✅ .
# • Mercancia[82] ❌ : Para "BienesTransp":"01010101", el campo "MaterialPeligroso" debe ser incluido según lo indicado en los catálogos del SAT (0,1)
# • Mercancia[83] ✅ .
# • Mercancia[84] ✅ .
# • Mercancia[85] ✅ .
# • Mercancia[86] ✅ .
# • Mercancia[87] ✅ .
# • Mercancia[88] ✅ .
# • Mercancia[89] ✅ .
# • Mercancia[90] ✅ .
# • Mercancia[91] ✅ .
# • Mercancia[92] ✅ .
# • Mercancia[93] ✅ .
# • Mercancia[94] ✅ .
# • Mercancia[95] ✅ .
# • Mercancia[96] ✅ .
# • Mercancia[97] ✅ .
# • Mercancia[98] ✅ .
# • Mercancia[99] ✅ .
# • Mercancia[100] ✅ .
# • Mercancia[101] ✅ .
# • Mercancia[102] ✅ .
# • Mercancia[103] ✅ .
# • Mercancia[104] ❌ : Para "BienesTransp":"01010101", el campo "MaterialPeligroso" debe ser incluido según lo indicado en los catálogos del SAT (0,1)
# • Mercancia[105] ✅ .
# • Mercancia[106] ✅ .
# • Mercancia[107] ✅ .
# • Mercancia[108] ✅ .
# • Mercancia[109] ✅ .
# • Mercancia[110] ✅ .
# • Mercancia[111] ✅ .
# • Mercancia[112] ✅ .
# • Mercancia[113] ✅ .
# • Mercancia[114] ✅ .
# • Mercancia[115] ✅ .
# • Mercancia[116] ✅ .
# • Mercancia[117] ✅ .
# • Mercancia[118] ✅ .
# • Mercancia[119] ✅ .
# • Mercancia[120] ✅ .
# • Mercancia[121] ✅ .
# • Mercancia[122] ✅ .
# • Mercancia[123] ✅ .
# • Mercancia[124] ❌ : Para "BienesTransp":"20122100", el campo "MaterialPeligroso" debe ser incluido según lo indicado en los catálogos del SAT (0,1)
# • Mercancia[125] ✅ .
# • Mercancia[126] ✅ .
# • Mercancia[127] ✅ .
# • Mercancia[128] ✅ .
# • Mercancia[129] ✅ .
# • Mercancia[130] ✅ .
# • Mercancia[131] ✅ .
# • Mercancia[132] ✅ .
# • Mercancia[133] ✅ .
# • Mercancia[134] ✅ .
# • Mercancia[135] ✅ .
# • Mercancia[136] ✅ .
# • Mercancia[137] ✅ .
# • Mercancia[138] ✅ .
# • Mercancia[139] ✅ .
# • Mercancia[140] ✅ .
# • Mercancia[141] ✅ .
# • Mercancia[142] ✅ .
# • Mercancia[143] ✅ .
# • Mercancia[144] ✅ .
# • Mercancia[145] ✅ .
# • Mercancia[146] ✅ .
# • Mercancia[147] ❌ : Para "BienesTransp":"01010101", el campo "MaterialPeligroso" debe ser incluido según lo indicado en los catálogos del SAT (0,1)
# • Mercancia[148] ✅ .
# • Mercancia[149] ❌ : Para "BienesTransp":"01010101", el campo "MaterialPeligroso" debe ser incluido según lo indicado en los catálogos del SAT (0,1)
